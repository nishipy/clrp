# %% [markdown]
# # Prerequisite

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue Jul 20 07:23:19 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Install same version of library as Kaggle Notebook

# %%
# !cp -f /content/drive/MyDrive/kaggle/commonlit/roberta-large/requirements.txt ./
# !cat ./requirements.txt
# Out:
# #pandas==1.2.3
# sklearn==0.0
# sklearn-pandas==2.1.0
# torch==1.7.0
# torchmetrics==0.2.0
# #torchtext==0.8.0a0+cd6902d
# torchvision==0.8.1
# transformers==4.5.1
# datasets==1.9.0
# accelerate==0.3.0

# %%
# !pip uninstall -r ./requirements.txt -y
# Out:
# Found existing installation: sklearn 0.0
# Uninstalling sklearn-0.0:
#   Successfully uninstalled sklearn-0.0
# Found existing installation: sklearn-pandas 1.8.0
# Uninstalling sklearn-pandas-1.8.0:
#   Successfully uninstalled sklearn-pandas-1.8.0
# Found existing installation: torch 1.9.0+cu102
# Uninstalling torch-1.9.0+cu102:
#   Successfully uninstalled torch-1.9.0+cu102
# WARNING: Skipping torchmetrics as it is not installed.
# Found existing installation: torchvision 0.10.0+cu102
# Uninstalling torchvision-0.10.0+cu102:
#   Successfully uninstalled torchvision-0.10.0+cu102
# WARNING: Skipping transformers as it is not installed.
# WARNING: Skipping datasets as it is not installed.
# WARNING: Skipping accelerate as it is not installed.

# %%
# !pip install -r ./requirements.txt
# Out:
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting sklearn-pandas==2.1.0
#   Downloading sklearn_pandas-2.1.0-py2.py3-none-any.whl (10 kB)
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp37-cp37m-manylinux1_x86_64.whl (776.7 MB)
#      |████████████████████████████████| 776.7 MB 4.1 kB/s
# Collecting torchmetrics==0.2.0
#   Downloading torchmetrics-0.2.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 89.8 MB/s
# Collecting torchvision==0.8.1
#   Downloading torchvision-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (12.7 MB)
#      |████████████████████████████████| 12.7 MB 72.9 MB/s
# Collecting transformers==4.5.1
#   Downloading transformers-4.5.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 70.0 MB/s
# Collecting datasets==1.9.0
#   Downloading datasets-1.9.0-py3-none-any.whl (262 kB)
#      |████████████████████████████████| 262 kB 84.4 MB/s
# Collecting accelerate==0.3.0
#   Downloading accelerate-0.3.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 8.2 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn==0.0->-r ./requirements.txt (line 2)) (0.22.2.post1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from sklearn-pandas==2.1.0->-r ./requirements.txt (line 3)) (1.1.5)
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.2 MB/s
# Collecting scipy>=1.5.1
#   Downloading scipy-1.7.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from sklearn-pandas==2.1.0->-r ./requirements.txt (line 3)) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r ./requirements.txt (line 4)) (3.7.4.3)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r ./requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.8.1->-r ./requirements.txt (line 7)) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r ./requirements.txt (line 8)) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r ./requirements.txt (line 8)) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r ./requirements.txt (line 8)) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r ./requirements.txt (line 8)) (21.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 79.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r ./requirements.txt (line 8)) (4.6.1)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 70.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r ./requirements.txt (line 8)) (3.0.12)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 78.6 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.9.0->-r ./requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.9.0->-r ./requirements.txt (line 9)) (0.3.4)
# Collecting huggingface-hub<0.1.0
#   Downloading huggingface_hub-0.0.14-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 86.7 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.9.0->-r ./requirements.txt (line 9)) (0.70.12.2)
# Collecting pyaml>=20.4.0
#   Downloading pyaml-20.4.0-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.5.1->-r ./requirements.txt (line 8)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->sklearn-pandas==2.1.0->-r ./requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->sklearn-pandas==2.1.0->-r ./requirements.txt (line 3)) (2018.9)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=20.4.0->accelerate==0.3.0->-r ./requirements.txt (line 10)) (3.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->sklearn-pandas==2.1.0->-r ./requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 8)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 8)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 8)) (2021.5.30)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn==0.0->-r ./requirements.txt (line 2)) (1.0.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.1->-r ./requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1->-r ./requirements.txt (line 8)) (7.1.2)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=0c6b2cdac3c378b810263e0098b8e03f779f7ee9367d019ade9de25e27909877
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, dataclasses, xxhash, torch, tokenizers, scikit-learn, sacremoses, pyaml, huggingface-hub, fsspec, transformers, torchvision, torchmetrics, sklearn-pandas, sklearn, datasets, accelerate
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.7.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed accelerate-0.3.0 dataclasses-0.6 datasets-1.9.0 fsspec-2021.7.0 huggingface-hub-0.0.14 pyaml-20.4.0 sacremoses-0.0.45 scikit-learn-0.24.2 scipy-1.7.0 sklearn-0.0 sklearn-pandas-2.1.0 threadpoolctl-2.2.0 tokenizers-0.10.3 torch-1.7.0 torchmetrics-0.2.0 torchvision-0.8.1 transformers-4.5.1 xxhash-2.0.2

# %%
# !pip freeze |grep -e random -e math -e numpy -e pandas -e torch -e transformers -e sklearn -e gc
# Out:
# mpmath==1.2.1
# numpy==1.19.5
# pandas==1.1.5
# pandas-datareader==0.9.0
# pandas-gbq==0.13.3
# pandas-profiling==1.4.1
# sklearn==0.0
# sklearn-pandas==2.1.0
# tensorflow-gcs-config==2.5.0
# torch==1.7.0
# torchmetrics==0.2.0
# torchsummary==1.5.1
# torchtext==0.10.0
# torchvision==0.8.1
# transformers==4.5.1

# %% [markdown]
# ## Prepare dataset

# %% [markdown]
# ### kaggle.json

# %%
# !mkdir -p /root/.kaggle/
# !cp ./drive/MyDrive/kaggle/commonlit/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Competition dataset

# %%
# !mkdir -p ../input/commonlitreadabilityprize/
# !kaggle competitions download -c commonlitreadabilityprize -p ../input/commonlitreadabilityprize/
# !cp -f ./drive/MyDrive/kaggle/commonlit/train_stratiKfold.csv.zip ../input/commonlitreadabilityprize/
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading test.csv to ../input/commonlitreadabilityprize
#   0% 0.00/6.79k [00:00<?, ?B/s]
# 100% 6.79k/6.79k [00:00<00:00, 6.47MB/s]
# Downloading sample_submission.csv to ../input/commonlitreadabilityprize
#   0% 0.00/108 [00:00<?, ?B/s]
# 100% 108/108 [00:00<00:00, 102kB/s]
# Downloading train.csv.zip to ../input/commonlitreadabilityprize
#   0% 0.00/1.13M [00:00<?, ?B/s]
# 100% 1.13M/1.13M [00:00<00:00, 76.7MB/s]

# %%
# !unzip -o ../input/commonlitreadabilityprize/train.csv.zip -d ../input/commonlitreadabilityprize/
# !unzip -o ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip -d ../input/commonlitreadabilityprize/
# Out:
# Archive:  ../input/commonlitreadabilityprize/train.csv.zip
#   inflating: ../input/commonlitreadabilityprize/train.csv
# Archive:  ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip
#   inflating: ../input/commonlitreadabilityprize/train_stratiKfold.csv

# %%
# !ls ../input/commonlitreadabilityprize/
# Out:
# sample_submission.csv  train.csv      train_stratiKfold.csv
# test.csv	       train.csv.zip  train_stratiKfold.csv.zip

# %% [markdown]
# ### Pretrained RoBERTa Large
# - Pretrain RoBERTa Large in the same way as this notebook
#   - https://www.kaggle.com/maunish/clrp-pytorch-roberta-pretrain
# - Dataset:
#   - https://www.kaggle.com/iamnishipy/roberta-large-20210712191259-mlm

# %%
# !mkdir -p ../input/commonlitreadabilityprize/pretrained-model/
# !kaggle datasets download iamnishipy/roberta-large-20210712191259-mlm
# Out:
# Downloading roberta-large-20210712191259-mlm.zip to /content
# 100% 8.52G/8.53G [01:56<00:00, 55.9MB/s]
# 100% 8.53G/8.53G [01:56<00:00, 78.6MB/s]

# %%
# !unzip -o ./roberta-large-20210712191259-mlm.zip -d ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# Archive:  ./roberta-large-20210712191259-mlm.zip
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/merges.txt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/special_tokens_map.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/tokenizer_config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large/vocab.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1200/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1200/optimizer.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1200/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1200/scheduler.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1200/trainer_state.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1200/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1600/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1600/optimizer.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1600/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1600/scheduler.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1600/trainer_state.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large_chk/checkpoint-1600/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/text.txt

# %%
# !ls ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# clrp_roberta_large  clrp_roberta_large_chk  text.txt

# %% [markdown]
# # Overview
# This is kernel is almost the same as [Lightweight Roberta solution in PyTorch](https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch), but instead of "roberta-base", it starts from [Maunish's pre-trained model](https://www.kaggle.com/maunish/clrp-roberta-base).
#
# Acknowledgments: some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
#!pip install transformers accelerate datasets

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup
from transformers import get_linear_schedule_with_warmup

from sklearn.model_selection import KFold

import gc
gc.enable()

# %% [markdown]
# ## Prepare dataset

# %%
NUM_FOLDS = 5
NUM_EPOCHS = 3
BATCH_SIZE = 8
MAX_LEN = 248
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
ROBERTA_PATH = "../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large"
TOKENIZER_PATH = "../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large"
# ROBERTA_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
# TOKENIZER_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %%
train_df = pd.read_csv("../input/commonlitreadabilityprize/train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv("../input/commonlitreadabilityprize/test.csv")
submission_df = pd.read_csv("../input/commonlitreadabilityprize/sample_submission.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only
        self.text = df.excerpt.tolist()
        #self.text = [text.replace("\n", " ") for text in self.text]
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32)        
    
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            return (input_ids, attention_mask, target)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH)
        config.update({"output_hidden_states":True, 
                       "hidden_dropout_prob": 0.0,
                       "layer_norm_eps": 1e-7})                       
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)
        #https://towardsdatascience.com/attention-based-deep-multiple-instance-learning-1bb3df857e24
        # 768: node fully connected layer
        # 512: node attention layer
        # self.attention = nn.Sequential(            
        #     nn.Linear(768, 512),            
        #     nn.Tanh(),                       
        #     nn.Linear(512, 1),
        #     nn.Softmax(dim=1)
        # )        

        # self.regressor = nn.Sequential(                        
        #     nn.Linear(768, 1)                        
        # )


        #768 -> 1024
        #512 -> 768
        self.attention = nn.Sequential(            
            nn.Linear(1024, 768),            
            nn.Tanh(),                       
            nn.Linear(768, 1),
            nn.Softmax(dim=1)
        )        

        self.regressor = nn.Sequential(                        
            nn.Linear(1024, 1)                        
        )
        

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids,
                                      attention_mask=attention_mask)        

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        last_layer_hidden_states = roberta_output.hidden_states[-1]

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base).
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        weights = self.attention(last_layer_hidden_states)
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1)        
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(context_vector)

# %%
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval()            
    mse_sum = 0

    with torch.no_grad():
        for batch_num, (input_ids, attention_mask, target) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)                        
            target = target.to(DEVICE)           
            
            pred = model(input_ids, attention_mask)                       

            mse_sum += nn.MSELoss(reduction="sum")(pred.flatten(), target).item()
                

    return mse_sum / len(data_loader.dataset)

# %%
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval()

    result = np.zeros(len(data_loader.dataset))    
    index = 0
    
    with torch.no_grad():
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred = model(input_ids, attention_mask)                        

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu")
            index += pred.shape[0]

    return result

# %%
def train(model, model_path, train_loader, val_loader,
          optimizer, scheduler=None, num_epochs=NUM_EPOCHS):    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1]    

    start = time.time()

    for epoch in range(num_epochs):                           
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target) in enumerate(train_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)            
            target = target.to(DEVICE)                        

            optimizer.zero_grad()
            
            model.train()

            pred = model(input_ids, attention_mask)
                                                        
            mse = nn.MSELoss(reduction="mean")(pred.flatten(), target)
                        
            mse.backward()

            optimizer.step()
            if scheduler:
                scheduler.step()
            
            if step >= last_eval_step + eval_period:
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start
                num_steps = step - last_eval_step
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step
                
                val_rmse = math.sqrt(eval_mse(model, val_loader))                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse: {val_rmse:0.4}")

                for rmse, period in EVAL_SCHEDULE:
                    if val_rmse >= rmse:
                        eval_period = period
                        break                               
                
                if not best_val_rmse or val_rmse < best_val_rmse:                    
                    best_val_rmse = val_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path)
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}",
                          f"(from epoch {best_epoch})")                                    
                    
                start = time.time()
                                            
            step += 1
                        
    
    return best_val_rmse

# %%
#怪しい
def create_optimizer(model):
    #model.named_parameters():
    #Base -> 205
    #Large -> 397
    named_parameters = list(model.named_parameters())    

    #Base
    # roberta_parameters = named_parameters[:197]    
    # attention_parameters = named_parameters[199:203]
    # regressor_parameters = named_parameters[203:]
    
    #Large
    roberta_parameters = named_parameters[:389]    
    attention_parameters = named_parameters[391:395]
    regressor_parameters = named_parameters[395:]
        
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]

    parameters = []
    parameters.append({"params": attention_group})
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if "bias" in name else 0.01
        lr = 2e-5
        #roberta-base: 
        # if layer_num >= 69: #4/12layers       
        #     lr = 5e-5
        # if layer_num >= 1f33: #8/12layers
        #     lr = 1e-4
        #roberta-large
        if layer_num >= 133: #8/24layers     
            lr = 5e-5
        if layer_num >= 261: #16/24layers
            lr = 1e-4


        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters)

# %%
# SEED = 1000
# kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
# for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):
#     print(fold)
#     print('------------')
#     print(val_indices)

# %% [markdown]
# # Debug

# %%
model = LitModel().to(DEVICE)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
named_parameters = list(model.named_parameters())
len(named_parameters)
# Out:
# 397

# %%
# for name, param in model.named_parameters():
#     print(name)

# %% [markdown]
# # Train

# %%
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth"
        
    set_random_seed(SEED + fold)
    
    train_dataset = LitDataset(train_df.loc[train_indices])    
    val_dataset = LitDataset(train_df.loc[val_indices])    
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2)    
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold)    
    
    model = LitModel().to(DEVICE)
    
    optimizer = create_optimizer(model)                        
    # scheduler = get_cosine_schedule_with_warmup(
    #     optimizer,
    #     num_training_steps=NUM_EPOCHS * len(train_loader),
    #     num_warmup_steps=50)
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=200)
    
    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler))

    del model
    gc.collect()
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.7 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9948
# New best_val_rmse: 0.9948
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7868
# New best_val_rmse: 0.7868
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 1.03
# Still best_val_rmse: 0.7868 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7324
# New best_val_rmse: 0.7324
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6477
# New best_val_rmse: 0.6477
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7103
# Still best_val_rmse: 0.6477 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.593
# New best_val_rmse: 0.593
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.8043
# Still best_val_rmse: 0.593 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6618
# Still best_val_rmse: 0.593 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.5791
# New best_val_rmse: 0.5791
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.6277
# Still best_val_rmse: 0.5791 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.886
# Still best_val_rmse: 0.5791 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.5578
# New best_val_rmse: 0.5578
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.601
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.5653
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5718
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.6504
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.5914
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5885
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.5766
# Still best_val_rmse: 0.5578 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5484
# New best_val_rmse: 0.5484
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.6518
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5485
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.7283
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 117 val_rmse: 1.198
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 133 val_rmse: 1.058
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 149 val_rmse: 1.023
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 165 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 181 val_rmse: 1.034
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 197 val_rmse: 1.019
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 213 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 229 val_rmse: 1.023
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 245 val_rmse: 1.021
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 261 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 277 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 10 val_rmse: 1.031
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 26 val_rmse: 1.022
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 42 val_rmse: 1.029
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 58 val_rmse: 1.042
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 74 val_rmse: 1.029
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 90 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 106 val_rmse: 1.021
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 122 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 138 val_rmse: 1.023
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 154 val_rmse: 1.019
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 170 val_rmse: 1.02
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 186 val_rmse: 1.02
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 202 val_rmse: 1.019
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 218 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 234 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 250 val_rmse: 1.018
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 266 val_rmse: 1.019
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 282 val_rmse: 1.019
# Still best_val_rmse: 0.5484 (from epoch 1)
#
# Performance estimates:
# [0.548392742915681]
# Mean: 0.548392742915681
#
# Fold 2/5
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.095
# New best_val_rmse: 1.095
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.9736
# New best_val_rmse: 0.9736
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7386
# New best_val_rmse: 0.7386
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7665
# Still best_val_rmse: 0.7386 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6394
# New best_val_rmse: 0.6394
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.6582
# Still best_val_rmse: 0.6394 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.7236
# Still best_val_rmse: 0.6394 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6049
# New best_val_rmse: 0.6049
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6561
# Still best_val_rmse: 0.6049 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.621
# Still best_val_rmse: 0.6049 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.6144
# Still best_val_rmse: 0.6049 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.7224
# Still best_val_rmse: 0.6049 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.6104
# Still best_val_rmse: 0.6049 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.6816
# Still best_val_rmse: 0.6049 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.599
# New best_val_rmse: 0.599
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5505
# New best_val_rmse: 0.5505
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5532
# Still best_val_rmse: 0.5505 (from epoch 0)
#
# 16 steps took 12.0 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.7005
# Still best_val_rmse: 0.5505 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.6511
# Still best_val_rmse: 0.5505 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.5577
# Still best_val_rmse: 0.5505 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5327
# New best_val_rmse: 0.5327
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5621
# Still best_val_rmse: 0.5327 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5645
# Still best_val_rmse: 0.5327 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.5759
# Still best_val_rmse: 0.5327 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.5336
# Still best_val_rmse: 0.5327 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.6096
# Still best_val_rmse: 0.5327 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.5047
# New best_val_rmse: 0.5047
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.507
# Still best_val_rmse: 0.5047 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.5282
# Still best_val_rmse: 0.5047 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 197 val_rmse: 0.5726
# Still best_val_rmse: 0.5047 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 213 val_rmse: 0.5757
# Still best_val_rmse: 0.5047 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 229 val_rmse: 0.5549
# Still best_val_rmse: 0.5047 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 245 val_rmse: 0.5646
# Still best_val_rmse: 0.5047 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 261 val_rmse: 0.501
# New best_val_rmse: 0.501
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 277 val_rmse: 0.512
# Still best_val_rmse: 0.501 (from epoch 1)
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.5053
# Still best_val_rmse: 0.501 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4971
# New best_val_rmse: 0.4971
#
# 8 steps took 5.89 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4983
# Still best_val_rmse: 0.4971 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4842
# New best_val_rmse: 0.4842
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4882
# Still best_val_rmse: 0.4842 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4866
# Still best_val_rmse: 0.4842 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4883
# Still best_val_rmse: 0.4842 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4778
# New best_val_rmse: 0.4778
#
# 2 steps took 1.49 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4785
# Still best_val_rmse: 0.4778 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.478
# Still best_val_rmse: 0.4778 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4785
# Still best_val_rmse: 0.4778 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4806
# Still best_val_rmse: 0.4778 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4757
# New best_val_rmse: 0.4757
#
# 2 steps took 1.48 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4777
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.482
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4789
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4799
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4759
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4743
# New best_val_rmse: 0.4743
#
# 2 steps took 1.48 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4725
# New best_val_rmse: 0.4725
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4899
# Still best_val_rmse: 0.4725 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4823
# Still best_val_rmse: 0.4725 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4743
# Still best_val_rmse: 0.4725 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4813
# Still best_val_rmse: 0.4725 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4705
# New best_val_rmse: 0.4705
#
# 2 steps took 1.48 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.477
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4837
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4911
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4713
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4771
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4751
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4776
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4846
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4817
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4789
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4812
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4912
# Still best_val_rmse: 0.4705 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 148 val_rmse: 0.4692
# New best_val_rmse: 0.4692
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 149 val_rmse: 0.469
# New best_val_rmse: 0.469
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 150 val_rmse: 0.47
# Still best_val_rmse: 0.469 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 151 val_rmse: 0.4728
# Still best_val_rmse: 0.469 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 153 val_rmse: 0.4724
# Still best_val_rmse: 0.469 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 155 val_rmse: 0.468
# New best_val_rmse: 0.468
#
# 1 steps took 0.749 seconds
# Epoch: 2 batch_num: 156 val_rmse: 0.4769
# Still best_val_rmse: 0.468 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 158 val_rmse: 0.5049
# Still best_val_rmse: 0.468 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 174 val_rmse: 0.4657
# New best_val_rmse: 0.4657
#
# 1 steps took 0.744 seconds
# Epoch: 2 batch_num: 175 val_rmse: 0.467
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 176 val_rmse: 0.4702
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 178 val_rmse: 0.4776
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 180 val_rmse: 0.4818
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 184 val_rmse: 0.4731
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 186 val_rmse: 0.4714
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 188 val_rmse: 0.4737
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 190 val_rmse: 0.4759
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 192 val_rmse: 0.4746
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 194 val_rmse: 0.4746
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 196 val_rmse: 0.4753
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 198 val_rmse: 0.4809
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 202 val_rmse: 0.4807
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 206 val_rmse: 0.4678
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 207 val_rmse: 0.467
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 208 val_rmse: 0.4665
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 209 val_rmse: 0.4663
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 210 val_rmse: 0.4661
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 211 val_rmse: 0.4662
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 212 val_rmse: 0.4661
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 213 val_rmse: 0.4662
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 214 val_rmse: 0.4661
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 215 val_rmse: 0.466
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 216 val_rmse: 0.4658
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 217 val_rmse: 0.4659
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 218 val_rmse: 0.466
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 219 val_rmse: 0.4663
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 220 val_rmse: 0.467
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 221 val_rmse: 0.4682
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.728 seconds
# Epoch: 2 batch_num: 222 val_rmse: 0.4682
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 223 val_rmse: 0.468
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 224 val_rmse: 0.4678
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.728 seconds
# Epoch: 2 batch_num: 225 val_rmse: 0.4673
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 226 val_rmse: 0.4667
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 227 val_rmse: 0.466
# Still best_val_rmse: 0.4657 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 228 val_rmse: 0.4656
# New best_val_rmse: 0.4656
#
# 1 steps took 0.744 seconds
# Epoch: 2 batch_num: 229 val_rmse: 0.4656
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 230 val_rmse: 0.466
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 231 val_rmse: 0.4662
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 232 val_rmse: 0.4666
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 233 val_rmse: 0.4672
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 234 val_rmse: 0.4675
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 235 val_rmse: 0.4673
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 236 val_rmse: 0.468
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 237 val_rmse: 0.4682
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 238 val_rmse: 0.4685
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 239 val_rmse: 0.4691
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 240 val_rmse: 0.4697
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.721 seconds
# Epoch: 2 batch_num: 241 val_rmse: 0.4707
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 243 val_rmse: 0.4711
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 245 val_rmse: 0.472
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 247 val_rmse: 0.4706
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 249 val_rmse: 0.4697
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 250 val_rmse: 0.4686
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 251 val_rmse: 0.4679
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 252 val_rmse: 0.4673
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 253 val_rmse: 0.4668
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 254 val_rmse: 0.4664
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 255 val_rmse: 0.4663
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 256 val_rmse: 0.4663
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 257 val_rmse: 0.4666
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.467
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 259 val_rmse: 0.4674
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 260 val_rmse: 0.4678
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 261 val_rmse: 0.4685
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.725 seconds
# Epoch: 2 batch_num: 262 val_rmse: 0.4687
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.726 seconds
# Epoch: 2 batch_num: 263 val_rmse: 0.4688
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 264 val_rmse: 0.469
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 265 val_rmse: 0.469
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.469
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 267 val_rmse: 0.469
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 268 val_rmse: 0.4689
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 269 val_rmse: 0.469
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 270 val_rmse: 0.4688
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 271 val_rmse: 0.4688
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 272 val_rmse: 0.4687
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 273 val_rmse: 0.4684
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4683
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.724 seconds
# Epoch: 2 batch_num: 275 val_rmse: 0.468
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 276 val_rmse: 0.4678
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 277 val_rmse: 0.4677
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 278 val_rmse: 0.4675
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 279 val_rmse: 0.4674
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.722 seconds
# Epoch: 2 batch_num: 280 val_rmse: 0.4672
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 281 val_rmse: 0.4671
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# 1 steps took 0.723 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.467
# Still best_val_rmse: 0.4656 (from epoch 2)
#
# Performance estimates:
# [0.548392742915681, 0.4655990463796272]
# Mean: 0.506995894647654
#
# Fold 3/5
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.084
# New best_val_rmse: 1.084
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 1.005
# New best_val_rmse: 1.005
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.8805
# New best_val_rmse: 0.8805
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.8542
# New best_val_rmse: 0.8542
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6538
# New best_val_rmse: 0.6538
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7449
# Still best_val_rmse: 0.6538 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.7316
# Still best_val_rmse: 0.6538 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.7962
# Still best_val_rmse: 0.6538 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.653
# New best_val_rmse: 0.653
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.6611
# Still best_val_rmse: 0.653 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.6103
# New best_val_rmse: 0.6103
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.71
# Still best_val_rmse: 0.6103 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.6133
# Still best_val_rmse: 0.6103 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.5593
# New best_val_rmse: 0.5593
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.6052
# Still best_val_rmse: 0.5593 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5829
# Still best_val_rmse: 0.5593 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5885
# Still best_val_rmse: 0.5593 (from epoch 0)
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.6377
# Still best_val_rmse: 0.5593 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5512
# New best_val_rmse: 0.5512
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.5628
# Still best_val_rmse: 0.5512 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.6139
# Still best_val_rmse: 0.5512 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.6535
# Still best_val_rmse: 0.5512 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.683
# Still best_val_rmse: 0.5512 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.5383
# New best_val_rmse: 0.5383
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.5434
# Still best_val_rmse: 0.5383 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.6351
# Still best_val_rmse: 0.5383 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.5298
# New best_val_rmse: 0.5298
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.5417
# Still best_val_rmse: 0.5298 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.5394
# Still best_val_rmse: 0.5298 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 197 val_rmse: 0.544
# Still best_val_rmse: 0.5298 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 213 val_rmse: 0.5384
# Still best_val_rmse: 0.5298 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 229 val_rmse: 0.5239
# New best_val_rmse: 0.5239
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 245 val_rmse: 0.5289
# Still best_val_rmse: 0.5239 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 261 val_rmse: 0.5041
# New best_val_rmse: 0.5041
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 277 val_rmse: 0.5888
# Still best_val_rmse: 0.5041 (from epoch 1)
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.5425
# Still best_val_rmse: 0.5041 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.5249
# Still best_val_rmse: 0.5041 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.5104
# Still best_val_rmse: 0.5041 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.5003
# New best_val_rmse: 0.5003
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.5181
# Still best_val_rmse: 0.5003 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.5047
# Still best_val_rmse: 0.5003 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4964
# New best_val_rmse: 0.4964
#
# 8 steps took 5.89 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.481
# New best_val_rmse: 0.481
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4865
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.5099
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.5045
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 154 val_rmse: 0.4936
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 162 val_rmse: 0.4889
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 166 val_rmse: 0.4964
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.88 seconds
# Epoch: 2 batch_num: 174 val_rmse: 0.4987
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.88 seconds
# Epoch: 2 batch_num: 182 val_rmse: 0.5211
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 198 val_rmse: 0.4884
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 202 val_rmse: 0.4844
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 206 val_rmse: 0.4926
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 214 val_rmse: 0.4987
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 222 val_rmse: 0.497
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 230 val_rmse: 0.4912
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.88 seconds
# Epoch: 2 batch_num: 238 val_rmse: 0.4853
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 242 val_rmse: 0.4868
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 246 val_rmse: 0.4941
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.88 seconds
# Epoch: 2 batch_num: 254 val_rmse: 0.4885
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.4882
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 262 val_rmse: 0.4897
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.49
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4892
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 278 val_rmse: 0.4891
# Still best_val_rmse: 0.481 (from epoch 2)
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.4892
# Still best_val_rmse: 0.481 (from epoch 2)
#
# Performance estimates:
# [0.548392742915681, 0.4655990463796272, 0.4809660552147527]
# Mean: 0.49831928150335364
#
# Fold 4/5
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.127
# New best_val_rmse: 1.127
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.823
# New best_val_rmse: 0.823
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.759
# New best_val_rmse: 0.759
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6436
# New best_val_rmse: 0.6436
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6383
# New best_val_rmse: 0.6383
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.6689
# Still best_val_rmse: 0.6383 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.7232
# Still best_val_rmse: 0.6383 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6925
# Still best_val_rmse: 0.6383 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6663
# Still best_val_rmse: 0.6383 (from epoch 0)
#
# 16 steps took 11.8 seconds

# %% [markdown]
# # Inference

# %%
test_dataset = LitDataset(test_df, inference_only=True)

# %%
all_predictions = np.zeros((len(list_val_rmse), len(test_df)))

test_dataset = LitDataset(test_df, inference_only=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         drop_last=False, shuffle=False, num_workers=2)

for index in range(len(list_val_rmse)):            
    model_path = f"model_{index + 1}.pth"
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    
    model.to(DEVICE)
    
    all_predictions[index] = predict(model, test_loader)
    
    del model
    gc.collect()

# %%
predictions = all_predictions.mean(axis=0)
submission_df.target = predictions
print(submission_df)
#submission_df.to_csv("submission.csv", index=False)

# %% [markdown]
# ## Upload model

# %%
# !mkdir -p ./output/
# !cp -f ./model* ./output/
#CHANGEME
# !cp -f ./drive/MyDrive/kaggle/commonlit/pretrained-roberta-base/dataset-metadata.json ./output/dataset-metadata.json
# !sed -i -e "s/roberta-base/roberta-large-`TZ=JST-9 date +"%Y%m%d%H%M%S"`-sch/" ./output/dataset-metadata.json
# !sed -i -e "s/Roberta-base/Roberta-large-`TZ=JST-9 date +"%m%d%H%M%S"`-sch/" ./output/dataset-metadata.json
# !kaggle datasets create -p ./output/

# %%
# !cat ./output/dataset-metadata.json

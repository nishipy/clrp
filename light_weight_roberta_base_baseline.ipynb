# %% [markdown]
# <a href="https://colab.research.google.com/github/nishipy/clrp/blob/main/light_weight_roberta_base_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
# This is kernel is almost the same as [Lightweight Roberta solution in PyTorch](https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch), but instead of "roberta-base", it starts from [Maunish's pre-trained model](https://www.kaggle.com/maunish/clrp-roberta-base).
#
# Acknowledgments: some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).
#
# In addition, we use the [stratified_kfold train dataset](https://www.kaggle.com/takeshikobayashi/commonlit-train-datasetfor) training the model.

# %% [markdown]
# ## Original notebook
# - Lightweight Roberta solution
#   - https://www.kaggle.com/andretugan/pre-trained-roberta-solution-in-pytorch
# - pretraied with MLM
#   - https://www.kaggle.com/maunish/clrp-pytorch-roberta-pretrain

# %% [markdown]
# # Prepare

# %% [markdown]
# ## Checking GPU status

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun Jul  4 06:53:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    33W / 250W |   7491MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Download dataset from kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### kaggle.json

# %%
# !mkdir -p /root/.kaggle/
# !cp ./drive/MyDrive/kaggle/commonlit/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Competition dataset

# %%
# !mkdir -p ../input/commonlitreadabilityprize/
# !kaggle competitions download -c commonlitreadabilityprize -p ../input/commonlitreadabilityprize/
# !cp -f ./drive/MyDrive/kaggle/commonlit/train_stratiKfold.csv.zip ../input/commonlitreadabilityprize/
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading train.csv.zip to ../input/commonlitreadabilityprize
#   0% 0.00/1.13M [00:00<?, ?B/s]
# 100% 1.13M/1.13M [00:00<00:00, 78.2MB/s]
# Downloading sample_submission.csv to ../input/commonlitreadabilityprize
#   0% 0.00/108 [00:00<?, ?B/s]
# 100% 108/108 [00:00<00:00, 91.7kB/s]
# Downloading test.csv to ../input/commonlitreadabilityprize
#   0% 0.00/6.79k [00:00<?, ?B/s]
# 100% 6.79k/6.79k [00:00<00:00, 6.90MB/s]

# %%
# !unzip -o ../input/commonlitreadabilityprize/train.csv.zip -d ../input/commonlitreadabilityprize/
# !unzip -o ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip -d ../input/commonlitreadabilityprize/
# Out:
# Archive:  ../input/commonlitreadabilityprize/train.csv.zip
#   inflating: ../input/commonlitreadabilityprize/train.csv
# Archive:  ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip
#   inflating: ../input/commonlitreadabilityprize/train_stratiKfold.csv

# %%
# !ls ../input/commonlitreadabilityprize/
# Out:
# sample_submission.csv  train.csv      train_stratiKfold.csv
# test.csv	       train.csv.zip  train_stratiKfold.csv.zip

# %% [markdown]
# ### Model pre-trained with MLM
# - Notebook
#   - https://www.kaggle.com/maunish/clrp-pytorch-roberta-pretrain
# - Model data
#   - https://www.kaggle.com/maunish/clrp-roberta-base

# %%
# !mkdir -p ../input/commonlitreadabilityprize/pretrained-model/
# !kaggle datasets download maunish/clrp-roberta-base -p ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# Downloading clrp-roberta-base.zip to ../input/commonlitreadabilityprize/pretrained-model
# 100% 3.00G/3.01G [00:25<00:00, 111MB/s]
# 100% 3.01G/3.01G [00:25<00:00, 128MB/s]

# %%
# !unzip -o ../input/commonlitreadabilityprize/pretrained-model/clrp-roberta-base.zip -d ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# Archive:  ../input/commonlitreadabilityprize/pretrained-model/clrp-roberta-base.zip
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/merges.txt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/special_tokens_map.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/tokenizer_config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/vocab.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/optimizer.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/scheduler.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/trainer_state.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/optimizer.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/scheduler.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/trainer_state.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/text.txt

# %% [markdown]
# # Install dependencies

# %%
# !pip install transformers accelerate datasets
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/fd/1a/41c644c963249fd7f3836d926afa1e3f1cc234a1c40d80c5f03ad8f6f1b2/transformers-4.8.2-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 7.9MB/s
# Collecting accelerate
#   Downloading https://files.pythonhosted.org/packages/f7/fa/d173d923c953d930702066894abf128a7e5258c6f64cf088d2c5a83f46a3/accelerate-0.3.0-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages/08/a2/d4e1024c891506e1cee8f9d719d20831bac31cb5b7416983c4d2f65a6287/datasets-1.8.0-py3-none-any.whl (237kB)
#      |████████████████████████████████| 245kB 60.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 42.4MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers) (3.13)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 43.2MB/s
# Collecting huggingface-hub==0.0.12
#   Downloading https://files.pythonhosted.org/packages/2f/ee/97e253668fda9b17e968b3f97b2f8e53aa0127e8807d24a547687423fe0b/huggingface_hub-0.0.12-py3-none-any.whl
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyaml>=20.4.0
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from accelerate) (1.9.0+cu102)
# Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Collecting fsspec
#   Downloading https://files.pythonhosted.org/packages/0e/3a/666e63625a19883ae8e1674099e631f9737bd5478c4790e5ad49c5ac5261/fsspec-2021.6.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 60.0MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 54.8MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Installing collected packages: sacremoses, tokenizers, huggingface-hub, transformers, pyaml, accelerate, fsspec, xxhash, datasets
# Successfully installed accelerate-0.3.0 datasets-1.8.0 fsspec-2021.6.1 huggingface-hub-0.0.12 pyaml-20.4.0 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.8.2 xxhash-2.0.2

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup

from sklearn.model_selection import KFold

import gc
gc.enable()

# %% [markdown]
# # Set constant

# %%
NUM_FOLDS = 5
NUM_EPOCHS = 3
BATCH_SIZE = 16
MAX_LEN = 248
#(eval_rmse, step_size)
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
ROBERTA_PATH = "../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/"
TOKENIZER_PATH = "../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/"
#ROBERTA_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
#TOKENIZER_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
EVAL_SCHEDULE[0][1]
# Out:
# 16

# %% [markdown]
# # Define utility functions

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %% [markdown]
# train_dfには、Stratified kfold済みのデータセットを利用する。

# %%
#Use stratified k-fold train dataset
#train_df = pd.read_csv("/kaggle/input/commonlitreadabilityprize/train.csv")
train_df = pd.read_csv("../input/commonlitreadabilityprize/train_stratiKfold.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv("../input/commonlitreadabilityprize/test.csv")
submission_df = pd.read_csv("../input/commonlitreadabilityprize/sample_submission.csv")

# %%
#TokenizerはRoberta-baseと同じ
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %%
train_df[train_df['kfold']!=1]
# Out:
#       Unnamed: 0         id  ... kfold bins
# 1              1  bf24448fb  ...     3    4
# 2              2  7cad0f936  ...     2    6
# 4              4  91e87e7dc  ...     2    7
# 5              5  20a9f9032  ...     4    5
# 6              6  daab29b47  ...     2    5
# ...          ...        ...  ...   ...  ...
# 2826        2827  d25b7c3aa  ...     2    6
# 2828        2829  3c1662f6d  ...     2    4
# 2830        2831  64b635d77  ...     2    9
# 2831        2832  d6764322c  ...     3   10
# 2832        2833  cf44e1a67  ...     2    9
#
# [2266 rows x 9 columns]

# %% [markdown]
# # Dataset

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only
        self.text = df.excerpt.tolist()
        #改行を消してみる。元のNotebookではここはコメントアウトされている
        #self.text = [text.replace("\n", " ") for text in self.text]
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32)        
    
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            return (input_ids, attention_mask, target)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH)
        #config.jsonに書いてある設定値を更新する
        config.update({"output_hidden_states":True, 
                       "hidden_dropout_prob": 0.0,
                       "layer_norm_eps": 1e-7})                       
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)  
            
        self.attention = nn.Sequential(            
            nn.Linear(768, 512),            
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )        

        self.regressor = nn.Sequential(                        
            nn.Linear(768, 1)                        
        )
        

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids,
                                      attention_mask=attention_mask)        

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        last_layer_hidden_states = roberta_output.hidden_states[-1]

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base).
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        weights = self.attention(last_layer_hidden_states)
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1)        
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(context_vector)

# %% [markdown]
# ## Define eval

# %%
#MSEで評価
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval()            
    mse_sum = 0

    with torch.no_grad():
        for batch_num, (input_ids, attention_mask, target) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)                        
            target = target.to(DEVICE)           
            
            pred = model(input_ids, attention_mask)                       

            mse_sum += nn.MSELoss(reduction="sum")(pred.flatten(), target).item()
                

    return mse_sum / len(data_loader.dataset)

# %% [markdown]
# ## Define predict

# %%
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval()

    result = np.zeros(len(data_loader.dataset))    
    index = 0
    
    with torch.no_grad():
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred = model(input_ids, attention_mask)                        

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu")
            index += pred.shape[0]

    return result

# %% [markdown]
# ### Define Train

# %%
def train(model, model_path, train_loader, val_loader,
          optimizer, scheduler=None, num_epochs=NUM_EPOCHS):    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    #EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
    #-> EVAL_SCHEDULE[0][1] = 16
    eval_period = EVAL_SCHEDULE[0][1]    

    start = time.time()

    #Epoch数だけ繰り返す
    for epoch in range(num_epochs):                           
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target) in enumerate(train_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)            
            target = target.to(DEVICE)                        

            optimizer.zero_grad()
            
            model.train()

            pred = model(input_ids, attention_mask)
                                                        
            mse = nn.MSELoss(reduction="mean")(pred.flatten(), target)
                        
            mse.backward()

            #https://stackoverflow.com/questions/60120043/optimizer-and-scheduler-for-bert-fine-tuning
            #`optimizer.step()`の直後、`scheduler.step()`をすべてのバッチで呼び出して、学習率を更新します。
            optimizer.step()
            if scheduler:
                scheduler.step()
            
            #eval_period(初期値は16）stepごとにRMSEを評価
            if step >= last_eval_step + eval_period:
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start
                num_steps = step - last_eval_step
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step
                
                val_rmse = math.sqrt(eval_mse(model, val_loader))                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse: {val_rmse:0.4}")

                #EVAL_SCHEDULEに定義したrmseによって
                #eval_periodを変更する
                for rmse, period in EVAL_SCHEDULE:
                    if val_rmse >= rmse:
                        eval_period = period
                        break                               
                
                #ベストスコアを記録
                if not best_val_rmse or val_rmse < best_val_rmse:                    
                    best_val_rmse = val_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path)
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}",
                          f"(from epoch {best_epoch})")                                    
                    
                start = time.time()

            #stepをインクリメント                                          
            step += 1
                        
    
    return best_val_rmse

# %% [markdown]
# ## Create Optimizer

# %%
def create_optimizer(model):
    named_parameters = list(model.named_parameters())    
    
    roberta_parameters = named_parameters[:197]    
    attention_parameters = named_parameters[199:203]
    regressor_parameters = named_parameters[203:]
        
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]

    parameters = []
    parameters.append({"params": attention_group})
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters)

# %% [markdown]
# ## Run

# %%
gc.collect()

SEED = 1000
list_val_rmse = []

for fold in range(NUM_FOLDS): 
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth"
        
    set_random_seed(SEED + fold)

    #Stratified kfold train dataset用に修正
    train_dataset = LitDataset(train_df[train_df['kfold']!=fold])    
    val_dataset = LitDataset(train_df[train_df['kfold']==fold])    
    
    #https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2)    
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
    
    #random_seedは、Foldごとに変わる
    set_random_seed(SEED + fold)    
    
    model = LitModel().to(DEVICE)
    
    optimizer = create_optimizer(model)
    #Schedulerには、get_cosine_schedule_with_warmupを使っている
    #その他の選択肢: https://huggingface.co/transformers/main_classes/optimizer_schedules.html#schedules                        
    scheduler = get_cosine_schedule_with_warmup(
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    
    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler))

    del model
    gc.collect()
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 7.07 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9574
# New best_val_rmse: 0.9574
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7136
# New best_val_rmse: 0.7136
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6355
# New best_val_rmse: 0.6355
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6181
# New best_val_rmse: 0.6181
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6541
# Still best_val_rmse: 0.6181 (from epoch 0)
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5713
# New best_val_rmse: 0.5713
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5811
# Still best_val_rmse: 0.5713 (from epoch 0)
#
# 16 steps took 6.32 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5241
# New best_val_rmse: 0.5241
#
# 16 steps took 6.46 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5121
# New best_val_rmse: 0.5121
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.514
# Still best_val_rmse: 0.5121 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.5455
# Still best_val_rmse: 0.5121 (from epoch 1)
#
# 16 steps took 6.34 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.4907
# New best_val_rmse: 0.4907
#
# 8 steps took 3.17 seconds
# Epoch: 1 batch_num: 59 val_rmse: 0.5458
# Still best_val_rmse: 0.4907 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 75 val_rmse: 0.4984
# Still best_val_rmse: 0.4907 (from epoch 1)
#
# 8 steps took 3.16 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.5508
# Still best_val_rmse: 0.4907 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 99 val_rmse: 0.4975
# Still best_val_rmse: 0.4907 (from epoch 1)
#
# 8 steps took 3.17 seconds
# Epoch: 1 batch_num: 107 val_rmse: 0.505
# Still best_val_rmse: 0.4907 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 123 val_rmse: 0.549
# Still best_val_rmse: 0.4907 (from epoch 1)
#
# 16 steps took 6.34 seconds
# Epoch: 1 batch_num: 139 val_rmse: 0.4813
# New best_val_rmse: 0.4813
#
# 4 steps took 1.74 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.4882
# Still best_val_rmse: 0.4813 (from epoch 1)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.4962
# Still best_val_rmse: 0.4813 (from epoch 1)
#
# 8 steps took 3.16 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.4795
# New best_val_rmse: 0.4795
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.4827
# Still best_val_rmse: 0.4795 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4816
# Still best_val_rmse: 0.4795 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4777
# New best_val_rmse: 0.4777
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4755
# New best_val_rmse: 0.4755
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4808
# Still best_val_rmse: 0.4755 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4784
# Still best_val_rmse: 0.4755 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4751
# New best_val_rmse: 0.4751
#
# 2 steps took 0.798 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4739
# New best_val_rmse: 0.4739
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4729
# New best_val_rmse: 0.4729
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4725
# New best_val_rmse: 0.4725
#
# 2 steps took 0.797 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.472
# New best_val_rmse: 0.472
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4715
# New best_val_rmse: 0.4715
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4718
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4752
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4781
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4769
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4734
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4719
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4714
# New best_val_rmse: 0.4714
#
# 2 steps took 0.795 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4716
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4712
# New best_val_rmse: 0.4712
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4711
# New best_val_rmse: 0.4711
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4717
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4732
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.474
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4737
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4742
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4736
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4738
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4738
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4738
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.474
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.475
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4762
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4764
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4764
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4754
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4743
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4739
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4737
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4734
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4736
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4744
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4752
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4756
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4757
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4759
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4756
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4754
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4752
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4751
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4751
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4751
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4752
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.796 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4752
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4752
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4752
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4751
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.785 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4751
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4751
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# Performance estimates:
# [0.471089345660429]
# Mean: 0.471089345660429
#
# Fold 2/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.027
# New best_val_rmse: 1.027
#
# 16 steps took 6.34 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7094
# New best_val_rmse: 0.7094
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.8308
# Still best_val_rmse: 0.7094 (from epoch 0)
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6959
# New best_val_rmse: 0.6959
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6494
# New best_val_rmse: 0.6494
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5598
# New best_val_rmse: 0.5598
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5814
# Still best_val_rmse: 0.5598 (from epoch 0)
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5336
# New best_val_rmse: 0.5336
#
# 16 steps took 6.47 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5179
# New best_val_rmse: 0.5179
#
# 16 steps took 6.34 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.5396
# Still best_val_rmse: 0.5179 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.505
# New best_val_rmse: 0.505
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.5113
# Still best_val_rmse: 0.505 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.5496
# Still best_val_rmse: 0.505 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.61
# Still best_val_rmse: 0.505 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 99 val_rmse: 0.4962
# New best_val_rmse: 0.4962
#
# 8 steps took 3.17 seconds
# Epoch: 1 batch_num: 107 val_rmse: 0.4942
# New best_val_rmse: 0.4942
#
# 8 steps took 3.17 seconds
# Epoch: 1 batch_num: 115 val_rmse: 0.5149
# Still best_val_rmse: 0.4942 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.5029
# Still best_val_rmse: 0.4942 (from epoch 1)
#
# 16 steps took 6.48 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.4899
# New best_val_rmse: 0.4899
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.4826
# New best_val_rmse: 0.4826
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.4959
# Still best_val_rmse: 0.4826 (from epoch 2)
#
# 8 steps took 3.16 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.5019
# Still best_val_rmse: 0.4826 (from epoch 2)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4801
# New best_val_rmse: 0.4801
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4792
# New best_val_rmse: 0.4792
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4812
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4811
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4797
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4796
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4807
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4796
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4796
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4799
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 2 steps took 0.792 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4801
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4807
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4811
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4818
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4835
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4816
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4826
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4869
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4887
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.59 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4857
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4832
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4816
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.481
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4809
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4808
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.59 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4808
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4808
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4808
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4808
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# Performance estimates:
# [0.471089345660429, 0.4791831833542291]
# Mean: 0.47513626450732904
#
# Fold 3/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9434
# New best_val_rmse: 0.9434
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.8244
# New best_val_rmse: 0.8244
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6613
# New best_val_rmse: 0.6613
#
# 16 steps took 6.32 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.5816
# New best_val_rmse: 0.5816
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6065
# Still best_val_rmse: 0.5816 (from epoch 0)
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5704
# New best_val_rmse: 0.5704
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.526
# New best_val_rmse: 0.526
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5661
# Still best_val_rmse: 0.526 (from epoch 0)
#
# 16 steps took 6.46 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.4947
# New best_val_rmse: 0.4947
#
# 8 steps took 3.16 seconds
# Epoch: 1 batch_num: 11 val_rmse: 0.5053
# Still best_val_rmse: 0.4947 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 27 val_rmse: 0.484
# New best_val_rmse: 0.484
#
# 4 steps took 1.58 seconds
# Epoch: 1 batch_num: 31 val_rmse: 0.507
# Still best_val_rmse: 0.484 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 47 val_rmse: 0.4669
# New best_val_rmse: 0.4669
#
# 1 steps took 0.395 seconds
# Epoch: 1 batch_num: 48 val_rmse: 0.4812
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 4 steps took 1.58 seconds
# Epoch: 1 batch_num: 52 val_rmse: 0.5085
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 68 val_rmse: 0.5238
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 84 val_rmse: 0.4703
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.791 seconds
# Epoch: 1 batch_num: 86 val_rmse: 0.478
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.787 seconds
# Epoch: 1 batch_num: 88 val_rmse: 0.4754
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.787 seconds
# Epoch: 1 batch_num: 90 val_rmse: 0.4712
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.787 seconds
# Epoch: 1 batch_num: 92 val_rmse: 0.516
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 108 val_rmse: 0.4758
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.788 seconds
# Epoch: 1 batch_num: 110 val_rmse: 0.4739
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.79 seconds
# Epoch: 1 batch_num: 112 val_rmse: 0.5057
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 128 val_rmse: 0.4711
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 2 steps took 0.787 seconds
# Epoch: 1 batch_num: 130 val_rmse: 0.4836
# Still best_val_rmse: 0.4669 (from epoch 1)
#
# 4 steps took 1.58 seconds
# Epoch: 1 batch_num: 134 val_rmse: 0.4596
# New best_val_rmse: 0.4596
#
# 1 steps took 0.394 seconds
# Epoch: 1 batch_num: 135 val_rmse: 0.4592
# New best_val_rmse: 0.4592
#
# 1 steps took 0.394 seconds
# Epoch: 1 batch_num: 136 val_rmse: 0.4647
# Still best_val_rmse: 0.4592 (from epoch 1)
#
# 1 steps took 0.393 seconds
# Epoch: 1 batch_num: 137 val_rmse: 0.4702
# Still best_val_rmse: 0.4592 (from epoch 1)
#
# 2 steps took 0.788 seconds
# Epoch: 1 batch_num: 139 val_rmse: 0.4581
# New best_val_rmse: 0.4581
#
# 1 steps took 0.392 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.4591
# Still best_val_rmse: 0.4581 (from epoch 1)
#
# 1 steps took 0.555 seconds
# Epoch: 2 batch_num: 0 val_rmse: 0.4664
# Still best_val_rmse: 0.4581 (from epoch 1)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 1 val_rmse: 0.4756
# Still best_val_rmse: 0.4581 (from epoch 1)
#
# 2 steps took 0.785 seconds
# Epoch: 2 batch_num: 3 val_rmse: 0.4855
# Still best_val_rmse: 0.4581 (from epoch 1)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 7 val_rmse: 0.458
# New best_val_rmse: 0.458
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.4599
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 9 val_rmse: 0.464
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.4633
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 11 val_rmse: 0.4618
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 12 val_rmse: 0.4607
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 13 val_rmse: 0.4599
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.4599
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 15 val_rmse: 0.4614
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.4636
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 17 val_rmse: 0.4683
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4718
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4759
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4702
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4636
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 25 val_rmse: 0.4635
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.396 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4635
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 27 val_rmse: 0.4645
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4643
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 29 val_rmse: 0.4627
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4611
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 31 val_rmse: 0.4607
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4614
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 33 val_rmse: 0.4649
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4727
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4818
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4753
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4716
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4625
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 45 val_rmse: 0.4592
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.458
# Still best_val_rmse: 0.458 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 47 val_rmse: 0.4575
# New best_val_rmse: 0.4575
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4576
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 49 val_rmse: 0.4594
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4627
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 51 val_rmse: 0.4663
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4692
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 53 val_rmse: 0.4717
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 55 val_rmse: 0.4756
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 57 val_rmse: 0.4829
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.4659
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4621
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4598
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4576
# Still best_val_rmse: 0.4575 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4561
# New best_val_rmse: 0.4561
#
# 1 steps took 0.401 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4552
# New best_val_rmse: 0.4552
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 67 val_rmse: 0.4548
# New best_val_rmse: 0.4548
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4547
# New best_val_rmse: 0.4547
#
# 1 steps took 0.395 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.4547
# New best_val_rmse: 0.4547
#
# 1 steps took 0.395 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4546
# New best_val_rmse: 0.4546
#
# 1 steps took 0.396 seconds
# Epoch: 2 batch_num: 71 val_rmse: 0.4547
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4546
# New best_val_rmse: 0.4546
#
# 1 steps took 0.396 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4546
# New best_val_rmse: 0.4546
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4547
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 75 val_rmse: 0.4549
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4553
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4556
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4557
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4561
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4573
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 81 val_rmse: 0.4589
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4609
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4632
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4648
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.4661
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.403 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4668
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4677
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4675
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.467
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4667
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4665
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4661
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.4662
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4662
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.4659
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4658
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.395 seconds
# Epoch: 2 batch_num: 97 val_rmse: 0.465
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4644
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.4638
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4631
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 101 val_rmse: 0.4623
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4614
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 103 val_rmse: 0.4605
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4598
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.398 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4594
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4588
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4584
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4581
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4579
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.397 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4577
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 111 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4575
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 113 val_rmse: 0.4574
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4574
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.4574
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4574
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 117 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 119 val_rmse: 0.4575
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 123 val_rmse: 0.4576
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4577
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 125 val_rmse: 0.4577
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4577
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4578
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4578
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4579
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4579
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4579
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.394 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4579
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.393 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4579
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.392 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# 1 steps took 0.391 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.458
# Still best_val_rmse: 0.4546 (from epoch 2)
#
# Performance estimates:
# [0.471089345660429, 0.4791831833542291, 0.45462613367895494]
# Mean: 0.46829955423120434
#
# Fold 4/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.059
# New best_val_rmse: 1.059
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.9468
# New best_val_rmse: 0.9468
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6678
# New best_val_rmse: 0.6678
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7191
# Still best_val_rmse: 0.6678 (from epoch 0)
#
# 16 steps took 6.32 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5933
# New best_val_rmse: 0.5933
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5677
# New best_val_rmse: 0.5677
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5987
# Still best_val_rmse: 0.5677 (from epoch 0)
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5183
# New best_val_rmse: 0.5183
#
# 16 steps took 6.49 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5294
# Still best_val_rmse: 0.5183 (from epoch 0)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.4895
# New best_val_rmse: 0.4895
#
# 4 steps took 1.59 seconds
# Epoch: 1 batch_num: 23 val_rmse: 0.5043
# Still best_val_rmse: 0.4895 (from epoch 1)
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 39 val_rmse: 0.4801
# New best_val_rmse: 0.4801
#
# 4 steps took 1.58 seconds
# Epoch: 1 batch_num: 43 val_rmse: 0.5345
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 59 val_rmse: 0.506
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 75 val_rmse: 0.4955
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 8 steps took 3.16 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.4979
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 8 steps took 3.16 seconds
# Epoch: 1 batch_num: 91 val_rmse: 0.5505
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 107 val_rmse: 0.5174
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 16 steps took 6.32 seconds
# Epoch: 1 batch_num: 123 val_rmse: 0.4915
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 8 steps took 3.16 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.4824
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 4 steps took 1.58 seconds
# Epoch: 1 batch_num: 135 val_rmse: 0.5234
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 16 steps took 6.48 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.5056
# Still best_val_rmse: 0.4801 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.473
# New best_val_rmse: 0.473
#
# 2 steps took 0.793 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4721
# New best_val_rmse: 0.4721
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4703
# New best_val_rmse: 0.4703
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4731
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4848
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4944
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 8 steps took 3.16 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4734
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4762
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.793 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4821
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4821
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.477
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4736
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4711
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4709
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4715
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4732
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4771
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.792 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4823
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4927
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 8 steps took 3.16 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.482
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4769
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4755
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4749
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4744
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4753
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4763
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4773
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.79 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4786
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4792
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.789 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4805
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4826
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4832
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4825
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4815
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4805
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 4 steps took 1.58 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4799
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4797
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.788 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4795
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.791 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4795
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.786 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4794
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# 2 steps took 0.787 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4794
# Still best_val_rmse: 0.4703 (from epoch 2)
#
# Performance estimates:
# [0.471089345660429, 0.4791831833542291, 0.45462613367895494, 0.4702727663542476]
# Mean: 0.4687928572619652
#
# Fold 5/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.8846
# New best_val_rmse: 0.8846
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7855
# New best_val_rmse: 0.7855
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6569
# New best_val_rmse: 0.6569
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6464
# New best_val_rmse: 0.6464
#
# 16 steps took 6.35 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6297
# New best_val_rmse: 0.6297
#
# 16 steps took 6.45 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.569
# New best_val_rmse: 0.569
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5649
# New best_val_rmse: 0.5649
#
# 16 steps took 6.33 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5454
# New best_val_rmse: 0.5454
#
# 16 steps took 6.48 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5239
# New best_val_rmse: 0.5239
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.5559
# Still best_val_rmse: 0.5239 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.5328
# Still best_val_rmse: 0.5239 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.5344
# Still best_val_rmse: 0.5239 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.5776
# Still best_val_rmse: 0.5239 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.5214
# New best_val_rmse: 0.5214
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 99 val_rmse: 0.5347
# Still best_val_rmse: 0.5214 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 115 val_rmse: 0.5271
# Still best_val_rmse: 0.5214 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.5265
# Still best_val_rmse: 0.5214 (from epoch 1)
#
# 16 steps took 6.48 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.53
# Still best_val_rmse: 0.5214 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.527
# Still best_val_rmse: 0.5214 (from epoch 1)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.5194
# New best_val_rmse: 0.5194
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.5311
# Still best_val_rmse: 0.5194 (from epoch 2)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.5279
# Still best_val_rmse: 0.5194 (from epoch 2)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.5142
# New best_val_rmse: 0.5142
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.5134
# New best_val_rmse: 0.5134
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.5159
# Still best_val_rmse: 0.5134 (from epoch 2)
#
# 16 steps took 6.33 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.5171
# Still best_val_rmse: 0.5134 (from epoch 2)
#
# Performance estimates:
# [0.471089345660429, 0.4791831833542291, 0.45462613367895494, 0.4702727663542476, 0.5134322286999178]
# Mean: 0.47772073154955574

# %% [markdown]
# # Inference

# %%
test_dataset = LitDataset(test_df, inference_only=True)

# %%
all_predictions = np.zeros((len(list_val_rmse), len(test_df)))

test_dataset = LitDataset(test_df, inference_only=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         drop_last=False, shuffle=False, num_workers=2)

for index in range(len(list_val_rmse)):            
    model_path = f"model_{index + 1}.pth"
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    
    model.to(DEVICE)
    
    all_predictions[index] = predict(model, test_loader)
    
    del model
    gc.collect()
# Out:
# Using model_1.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_2.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_3.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_4.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_5.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
predictions = all_predictions.mean(axis=0)
submission_df.target = predictions
print(submission_df)
submission_df.to_csv("submission.csv", index=False)
# Out:
#           id    target
# 0  c0f722661 -0.404446
# 1  f0953f0a5 -0.597980
# 2  0df072751 -0.258812
# 3  04caf4e0c -2.492555
# 4  0e63f8bea -1.670199
# 5  12537fe78 -1.504853
# 6  965e592c0  0.083787

# %% [markdown]
# # Upload data

# %%
# !date +"%Y%m%d%I%M%S"
# Out:
# 20210704055711

# %%
# !mkdir -p ./output/
# !cp -f ./model* ./output/
#CHANGEME
# !cp -f ./drive/MyDrive/kaggle/commonlit/Lightweight-Roberta-base/dataset-metadata.json ./output/dataset-metadata.json
# !sed -i -e "s/lightweight-roberta-base/lightweight-roberta-base-`date +"%Y%m%d%I%M%S"`/" ./output/dataset-metadata.json
# !kaggle datasets create -p ./output/
# Out:
# Starting upload for file model_3.pth
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# 100% 477M/477M [00:10<00:00, 46.1MB/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_5.pth
# 100% 477M/477M [00:12<00:00, 40.8MB/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_4.pth
# 100% 477M/477M [00:09<00:00, 53.3MB/s]
# Upload successful: model_4.pth (477MB)
# Starting upload for file model_2.pth
# 100% 477M/477M [00:11<00:00, 44.2MB/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_1.pth
# 100% 477M/477M [00:11<00:00, 42.5MB/s]
# Upload successful: model_1.pth (477MB)
# Your private Dataset is being created. Please check progress at /api/v1/datasets/status//iamnishipy/lightweight-roberta-base-20210704055800

# %%
# !cat ./output/dataset-metadata.json
# Out:
# {
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ],
#   "id": "iamnishipy/lightweight-roberta-base-20210704055731",
#   "title": "Lightweight-Roberta-base"
# }

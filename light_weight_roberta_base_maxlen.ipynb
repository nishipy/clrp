# %% [markdown]
# <a href="https://colab.research.google.com/github/nishipy/clrp/blob/main/light_weight_roberta_base_maxlen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
# This is kernel is almost the same as [Lightweight Roberta solution in PyTorch](https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch), but instead of "roberta-base", it starts from [Maunish's pre-trained model](https://www.kaggle.com/maunish/clrp-roberta-base).
#
# Acknowledgments: some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).
#
# In addition, we use the [stratified_kfold train dataset](https://www.kaggle.com/takeshikobayashi/commonlit-train-datasetfor) training the model.

# %% [markdown]
# ## Original notebook
# - Lightweight Roberta solution
#   - https://www.kaggle.com/andretugan/pre-trained-roberta-solution-in-pytorch
# - pretraied with MLM
#   - https://www.kaggle.com/maunish/clrp-pytorch-roberta-pretrain

# %% [markdown]
# # Prepare

# %% [markdown]
# ## Checking GPU status

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Jul  3 17:20:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Download dataset from kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### kaggle.json

# %%
# !mkdir -p /root/.kaggle/
# !cp ./drive/MyDrive/kaggle/commonlit/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Competition dataset

# %%
# !mkdir -p ../input/commonlitreadabilityprize/
# !kaggle competitions download -c commonlitreadabilityprize -p ../input/commonlitreadabilityprize/
# !cp -f ./drive/MyDrive/kaggle/commonlit/train_stratiKfold.csv.zip ../input/commonlitreadabilityprize/
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading sample_submission.csv to ../input/commonlitreadabilityprize
#   0% 0.00/108 [00:00<?, ?B/s]
# 100% 108/108 [00:00<00:00, 185kB/s]
# Downloading train.csv.zip to ../input/commonlitreadabilityprize
#   0% 0.00/1.13M [00:00<?, ?B/s]
# 100% 1.13M/1.13M [00:00<00:00, 75.2MB/s]
# Downloading test.csv to ../input/commonlitreadabilityprize
#   0% 0.00/6.79k [00:00<?, ?B/s]
# 100% 6.79k/6.79k [00:00<00:00, 7.00MB/s]

# %%
# !unzip -o ../input/commonlitreadabilityprize/train.csv.zip -d ../input/commonlitreadabilityprize/
# !unzip -o ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip -d ../input/commonlitreadabilityprize/
# Out:
# Archive:  ../input/commonlitreadabilityprize/train.csv.zip
#   inflating: ../input/commonlitreadabilityprize/train.csv
# Archive:  ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip
#   inflating: ../input/commonlitreadabilityprize/train_stratiKfold.csv

# %%
# !ls ../input/commonlitreadabilityprize/
# Out:
# sample_submission.csv  train.csv      train_stratiKfold.csv
# test.csv	       train.csv.zip  train_stratiKfold.csv.zip

# %% [markdown]
# ### Model pre-trained with MLM
# - Notebook
#   - https://www.kaggle.com/maunish/clrp-pytorch-roberta-pretrain
# - Model data
#   - https://www.kaggle.com/maunish/clrp-roberta-base

# %%
# !mkdir -p ../input/commonlitreadabilityprize/pretrained-model/
# !kaggle datasets download maunish/clrp-roberta-base -p ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# Downloading clrp-roberta-base.zip to ../input/commonlitreadabilityprize/pretrained-model
# 100% 3.00G/3.01G [00:55<00:00, 64.8MB/s]
# 100% 3.01G/3.01G [00:55<00:00, 57.7MB/s]

# %%
# !unzip -o ../input/commonlitreadabilityprize/pretrained-model/clrp-roberta-base.zip -d ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# Archive:  ../input/commonlitreadabilityprize/pretrained-model/clrp-roberta-base.zip
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/merges.txt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/special_tokens_map.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/tokenizer_config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/vocab.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/optimizer.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/scheduler.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/trainer_state.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-600/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/config.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/optimizer.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/pytorch_model.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/scheduler.pt
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/trainer_state.json
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base_chk/checkpoint-800/training_args.bin
#   inflating: ../input/commonlitreadabilityprize/pretrained-model/text.txt

# %% [markdown]
# # Install dependencies

# %%
# !pip install transformers accelerate datasets
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/fd/1a/41c644c963249fd7f3836d926afa1e3f1cc234a1c40d80c5f03ad8f6f1b2/transformers-4.8.2-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 10.0MB/s
# Collecting accelerate
#   Downloading https://files.pythonhosted.org/packages/f7/fa/d173d923c953d930702066894abf128a7e5258c6f64cf088d2c5a83f46a3/accelerate-0.3.0-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 6.0MB/s
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages/08/a2/d4e1024c891506e1cee8f9d719d20831bac31cb5b7416983c4d2f65a6287/datasets-1.8.0-py3-none-any.whl (237kB)
#      |████████████████████████████████| 245kB 38.8MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub==0.0.12
#   Downloading https://files.pythonhosted.org/packages/2f/ee/97e253668fda9b17e968b3f97b2f8e53aa0127e8807d24a547687423fe0b/huggingface_hub-0.0.12-py3-none-any.whl
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 33.4MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 34.5MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers) (3.13)
# Collecting pyaml>=20.4.0
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from accelerate) (1.9.0+cu102)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting fsspec
#   Downloading https://files.pythonhosted.org/packages/0e/3a/666e63625a19883ae8e1674099e631f9737bd5478c4790e5ad49c5ac5261/fsspec-2021.6.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 40.2MB/s
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 35.7MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.1)
# Installing collected packages: huggingface-hub, sacremoses, tokenizers, transformers, pyaml, accelerate, fsspec, xxhash, datasets
# Successfully installed accelerate-0.3.0 datasets-1.8.0 fsspec-2021.6.1 huggingface-hub-0.0.12 pyaml-20.4.0 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.8.2 xxhash-2.0.2

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup

from sklearn.model_selection import KFold

import gc
gc.enable()

# %% [markdown]
# # Set constant

# %%
NUM_FOLDS = 5
NUM_EPOCHS = 3
BATCH_SIZE = 16
MAX_LEN = 260
#MAX_LEN = 248
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
ROBERTA_PATH = "../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/"
TOKENIZER_PATH = "../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/"
#ROBERTA_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
#TOKENIZER_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # Define utility functions

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %% [markdown]
# train_dfには、Stratified kfold済みのデータセットを利用する。

# %%
#Use stratified k-fold train dataset
#train_df = pd.read_csv("/kaggle/input/commonlitreadabilityprize/train.csv")
train_df = pd.read_csv("../input/commonlitreadabilityprize/train_stratiKfold.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv("../input/commonlitreadabilityprize/test.csv")
submission_df = pd.read_csv("../input/commonlitreadabilityprize/sample_submission.csv")

# %%
#TokenizerはRoberta-baseと同じ
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only
        self.text = df.excerpt.tolist()
        #改行を消してみる。元のNotebookではここはコメントアウトされている
        #self.text = [text.replace("\n", " ") for text in self.text]
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32)        
    
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            return (input_ids, attention_mask, target)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH)
        #config.jsonに書いてある設定値を更新する
        config.update({"output_hidden_states":True, 
                       "hidden_dropout_prob": 0.0,
                       "layer_norm_eps": 1e-7})                       
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)  
            
        self.attention = nn.Sequential(            
            nn.Linear(768, 512),            
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )        

        self.regressor = nn.Sequential(                        
            nn.Linear(768, 1)                        
        )
        

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids,
                                      attention_mask=attention_mask)        

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        last_layer_hidden_states = roberta_output.hidden_states[-1]

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base).
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        weights = self.attention(last_layer_hidden_states)
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1)        
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(context_vector)

# %%
#MSEで評価
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval()            
    mse_sum = 0

    with torch.no_grad():
        for batch_num, (input_ids, attention_mask, target) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)                        
            target = target.to(DEVICE)           
            
            pred = model(input_ids, attention_mask)                       

            mse_sum += nn.MSELoss(reduction="sum")(pred.flatten(), target).item()
                

    return mse_sum / len(data_loader.dataset)

# %%
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval()

    result = np.zeros(len(data_loader.dataset))    
    index = 0
    
    with torch.no_grad():
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred = model(input_ids, attention_mask)                        

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu")
            index += pred.shape[0]

    return result

# %%
def train(model, model_path, train_loader, val_loader,
          optimizer, scheduler=None, num_epochs=NUM_EPOCHS):    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1]    

    start = time.time()

    for epoch in range(num_epochs):                           
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target) in enumerate(train_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)            
            target = target.to(DEVICE)                        

            optimizer.zero_grad()
            
            model.train()

            pred = model(input_ids, attention_mask)
                                                        
            mse = nn.MSELoss(reduction="mean")(pred.flatten(), target)
                        
            mse.backward()

            optimizer.step()
            if scheduler:
                scheduler.step()
            
            if step >= last_eval_step + eval_period:
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start
                num_steps = step - last_eval_step
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step
                
                val_rmse = math.sqrt(eval_mse(model, val_loader))                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse: {val_rmse:0.4}")

                for rmse, period in EVAL_SCHEDULE:
                    if val_rmse >= rmse:
                        eval_period = period
                        break                               
                
                if not best_val_rmse or val_rmse < best_val_rmse:                    
                    best_val_rmse = val_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path)
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}",
                          f"(from epoch {best_epoch})")                                    
                    
                start = time.time()
                                            
            step += 1
                        
    
    return best_val_rmse

# %%
def create_optimizer(model):
    named_parameters = list(model.named_parameters())    
    
    roberta_parameters = named_parameters[:197]    
    attention_parameters = named_parameters[199:203]
    regressor_parameters = named_parameters[203:]
        
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]

    parameters = []
    parameters.append({"params": attention_group})
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters)

# %% [markdown]
# ## Run

# %%
gc.collect()

SEED = 1000
list_val_rmse = []

for fold in range(NUM_FOLDS): 
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth"
        
    set_random_seed(SEED + fold)

    #Stratified kfold train dataset用に修正
    train_dataset = LitDataset(train_df[train_df['kfold']!=fold])    
    val_dataset = LitDataset(train_df[train_df['kfold']==fold])    
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2)    
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold)    
    
    model = LitModel().to(DEVICE)
    
    optimizer = create_optimizer(model)                        
    scheduler = get_cosine_schedule_with_warmup(
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    
    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler))

    del model
    gc.collect()
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())


#kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
#
# for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
#     print(f"\nFold {fold + 1}/{NUM_FOLDS}")
#     model_path = f"model_{fold + 1}.pth"
        
#     set_random_seed(SEED + fold)
    
#     train_dataset = LitDataset(train_df.loc[train_indices])    
#     val_dataset = LitDataset(train_df.loc[val_indices])    
        
#     train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
#                               drop_last=True, shuffle=True, num_workers=2)    
#     val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
#                             drop_last=False, shuffle=False, num_workers=2)    
        
#     set_random_seed(SEED + fold)    
    
#     model = LitModel().to(DEVICE)
    
#     optimizer = create_optimizer(model)                        
#     scheduler = get_cosine_schedule_with_warmup(
#         optimizer,
#         num_training_steps=NUM_EPOCHS * len(train_loader),
#         num_warmup_steps=50)    
    
#     list_val_rmse.append(train(model, model_path, train_loader,
#                                val_loader, optimizer, scheduler=scheduler))

#     del model
#     gc.collect()
    
#     print("\nPerformance estimates:")
#     print(list_val_rmse)
#     print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 7.64 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9604
# New best_val_rmse: 0.9604
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7144
# New best_val_rmse: 0.7144
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6295
# New best_val_rmse: 0.6295
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6116
# New best_val_rmse: 0.6116
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.619
# Still best_val_rmse: 0.6116 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.556
# New best_val_rmse: 0.556
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5833
# Still best_val_rmse: 0.556 (from epoch 0)
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.4913
# New best_val_rmse: 0.4913
#
# 8 steps took 3.42 seconds
# Epoch: 0 batch_num: 136 val_rmse: 0.4885
# New best_val_rmse: 0.4885
#
# 4 steps took 1.72 seconds
# Epoch: 0 batch_num: 140 val_rmse: 0.5316
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 16 steps took 7.03 seconds
# Epoch: 1 batch_num: 15 val_rmse: 0.4939
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 8 steps took 3.41 seconds
# Epoch: 1 batch_num: 23 val_rmse: 0.5401
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 39 val_rmse: 0.5508
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 55 val_rmse: 0.5247
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 16 steps took 6.82 seconds
# Epoch: 1 batch_num: 71 val_rmse: 0.5251
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 87 val_rmse: 0.5867
# Still best_val_rmse: 0.4885 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 103 val_rmse: 0.4826
# New best_val_rmse: 0.4826
#
# 4 steps took 1.73 seconds
# Epoch: 1 batch_num: 107 val_rmse: 0.5397
# Still best_val_rmse: 0.4826 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 123 val_rmse: 0.4777
# New best_val_rmse: 0.4777
#
# 2 steps took 0.863 seconds
# Epoch: 1 batch_num: 125 val_rmse: 0.4805
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.4965
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 8 steps took 3.42 seconds
# Epoch: 1 batch_num: 137 val_rmse: 0.4819
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 4 steps took 1.9 seconds
# Epoch: 2 batch_num: 0 val_rmse: 0.485
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 4 val_rmse: 0.4784
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.4783
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 2 steps took 0.865 seconds
# Epoch: 2 batch_num: 8 val_rmse: 0.4942
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 8 steps took 3.42 seconds
# Epoch: 2 batch_num: 16 val_rmse: 0.4782
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4787
# Still best_val_rmse: 0.4777 (from epoch 1)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 20 val_rmse: 0.4738
# New best_val_rmse: 0.4738
#
# 2 steps took 0.861 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4751
# Still best_val_rmse: 0.4738 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4784
# Still best_val_rmse: 0.4738 (from epoch 2)
#
# 2 steps took 0.859 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4739
# Still best_val_rmse: 0.4738 (from epoch 2)
#
# 2 steps took 0.859 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4726
# New best_val_rmse: 0.4726
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4722
# New best_val_rmse: 0.4722
#
# 2 steps took 0.863 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4725
# Still best_val_rmse: 0.4722 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4741
# Still best_val_rmse: 0.4722 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4764
# Still best_val_rmse: 0.4722 (from epoch 2)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4819
# Still best_val_rmse: 0.4722 (from epoch 2)
#
# 4 steps took 1.73 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4843
# Still best_val_rmse: 0.4722 (from epoch 2)
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4715
# New best_val_rmse: 0.4715
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.472
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4732
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4738
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.872 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4718
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.861 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4718
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.868 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4789
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4877
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4873
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4758
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.864 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.867 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4726
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.866 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.473
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4737
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4734
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.473
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.859 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4729
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.863 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4751
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4778
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.854 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4796
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4789
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.478
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4761
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.475
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.859 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4742
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4738
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4734
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.863 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4735
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4738
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4741
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4742
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.862 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.474
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4739
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4738
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.869 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4737
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.871 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4737
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.872 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4737
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.868 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4737
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4737
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.873 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.867 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.852 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4736
# Still best_val_rmse: 0.4715 (from epoch 2)
#
# Performance estimates:
# [0.4714620448305189]
# Mean: 0.4714620448305189
#
# Fold 2/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 7.42 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.026
# New best_val_rmse: 1.026
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.6859
# New best_val_rmse: 0.6859
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.8495
# Still best_val_rmse: 0.6859 (from epoch 0)
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7025
# Still best_val_rmse: 0.6859 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6291
# New best_val_rmse: 0.6291
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5553
# New best_val_rmse: 0.5553
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5804
# Still best_val_rmse: 0.5553 (from epoch 0)
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.536
# New best_val_rmse: 0.536
#
# 16 steps took 7.03 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5198
# New best_val_rmse: 0.5198
#
# 16 steps took 6.86 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.5527
# Still best_val_rmse: 0.5198 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.5079
# New best_val_rmse: 0.5079
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.5122
# Still best_val_rmse: 0.5079 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.5351
# Still best_val_rmse: 0.5079 (from epoch 1)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.5816
# Still best_val_rmse: 0.5079 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 99 val_rmse: 0.5015
# New best_val_rmse: 0.5015
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 115 val_rmse: 0.5096
# Still best_val_rmse: 0.5015 (from epoch 1)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.5095
# Still best_val_rmse: 0.5015 (from epoch 1)
#
# 16 steps took 7.01 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.4875
# New best_val_rmse: 0.4875
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.4928
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 8 steps took 3.43 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4902
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 8 steps took 3.42 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4852
# New best_val_rmse: 0.4852
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4835
# New best_val_rmse: 0.4835
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.484
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4806
# New best_val_rmse: 0.4806
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4812
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4816
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4831
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4836
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4835
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4847
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4897
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4868
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4823
# Still best_val_rmse: 0.4806 (from epoch 2)
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4804
# New best_val_rmse: 0.4804
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4803
# New best_val_rmse: 0.4803
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4806
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4809
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4812
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4811
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.481
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4808
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4808
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4808
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4808
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4809
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4809
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.481
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.481
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.481
# Still best_val_rmse: 0.4803 (from epoch 2)
#
# Performance estimates:
# [0.4714620448305189, 0.4803465694155351]
# Mean: 0.475904307123027
#
# Fold 3/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 7.43 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9399
# New best_val_rmse: 0.9399
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.851
# New best_val_rmse: 0.851
#
# 16 steps took 6.86 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6275
# New best_val_rmse: 0.6275
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.5774
# New best_val_rmse: 0.5774
#
# 16 steps took 6.86 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5765
# New best_val_rmse: 0.5765
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5399
# New best_val_rmse: 0.5399
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5001
# New best_val_rmse: 0.5001
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5771
# Still best_val_rmse: 0.5001 (from epoch 0)
#
# 16 steps took 7.03 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.4929
# New best_val_rmse: 0.4929
#
# 8 steps took 3.43 seconds
# Epoch: 1 batch_num: 11 val_rmse: 0.4956
# Still best_val_rmse: 0.4929 (from epoch 1)
#
# 8 steps took 3.42 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.4922
# New best_val_rmse: 0.4922
#
# 8 steps took 3.43 seconds
# Epoch: 1 batch_num: 27 val_rmse: 0.4905
# New best_val_rmse: 0.4905
#
# 8 steps took 3.42 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.5028
# Still best_val_rmse: 0.4905 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.5107
# Still best_val_rmse: 0.4905 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.5264
# Still best_val_rmse: 0.4905 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.4836
# New best_val_rmse: 0.4836
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 87 val_rmse: 0.486
# Still best_val_rmse: 0.4836 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 91 val_rmse: 0.4819
# New best_val_rmse: 0.4819
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 95 val_rmse: 0.4627
# New best_val_rmse: 0.4627
#
# 1 steps took 0.431 seconds
# Epoch: 1 batch_num: 96 val_rmse: 0.4711
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 2 steps took 0.861 seconds
# Epoch: 1 batch_num: 98 val_rmse: 0.4804
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 102 val_rmse: 0.4762
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 2 steps took 0.853 seconds
# Epoch: 1 batch_num: 104 val_rmse: 0.4961
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 8 steps took 3.43 seconds
# Epoch: 1 batch_num: 112 val_rmse: 0.5271
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 128 val_rmse: 0.4684
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.4643
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 1 steps took 0.435 seconds
# Epoch: 1 batch_num: 130 val_rmse: 0.4633
# Still best_val_rmse: 0.4627 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.4581
# New best_val_rmse: 0.4581
#
# 1 steps took 0.429 seconds
# Epoch: 1 batch_num: 132 val_rmse: 0.4562
# New best_val_rmse: 0.4562
#
# 1 steps took 0.436 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.4563
# Still best_val_rmse: 0.4562 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 1 batch_num: 134 val_rmse: 0.4572
# Still best_val_rmse: 0.4562 (from epoch 1)
#
# 1 steps took 0.444 seconds
# Epoch: 1 batch_num: 135 val_rmse: 0.4563
# Still best_val_rmse: 0.4562 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 1 batch_num: 136 val_rmse: 0.4587
# Still best_val_rmse: 0.4562 (from epoch 1)
#
# 1 steps took 0.428 seconds
# Epoch: 1 batch_num: 137 val_rmse: 0.4576
# Still best_val_rmse: 0.4562 (from epoch 1)
#
# 1 steps took 0.427 seconds
# Epoch: 1 batch_num: 138 val_rmse: 0.4535
# New best_val_rmse: 0.4535
#
# 1 steps took 0.433 seconds
# Epoch: 1 batch_num: 139 val_rmse: 0.458
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.428 seconds
# Epoch: 1 batch_num: 140 val_rmse: 0.4706
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 1 val_rmse: 0.5085
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 2 batch_num: 17 val_rmse: 0.4861
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 21 val_rmse: 0.4587
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.458
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 23 val_rmse: 0.4568
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.428 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4566
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 25 val_rmse: 0.4566
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4569
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 27 val_rmse: 0.4577
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.436 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.458
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.441 seconds
# Epoch: 2 batch_num: 29 val_rmse: 0.4577
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4577
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 31 val_rmse: 0.458
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4579
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 33 val_rmse: 0.4583
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 34 val_rmse: 0.4583
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 35 val_rmse: 0.4592
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 36 val_rmse: 0.4614
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.428 seconds
# Epoch: 2 batch_num: 37 val_rmse: 0.4656
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.4684
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.428 seconds
# Epoch: 2 batch_num: 39 val_rmse: 0.4729
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 2 steps took 0.854 seconds
# Epoch: 2 batch_num: 41 val_rmse: 0.4749
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 43 val_rmse: 0.4754
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 45 val_rmse: 0.4816
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 49 val_rmse: 0.4804
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 4 steps took 1.72 seconds
# Epoch: 2 batch_num: 53 val_rmse: 0.4671
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4651
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 55 val_rmse: 0.4635
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4614
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 57 val_rmse: 0.4596
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4586
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 59 val_rmse: 0.4578
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4571
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.433 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.4562
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4558
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4553
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.433 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4549
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4554
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4562
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 67 val_rmse: 0.4568
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4583
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.459
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4589
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 71 val_rmse: 0.4584
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4583
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4577
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4574
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 75 val_rmse: 0.4567
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 76 val_rmse: 0.4561
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4547
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4536
# Still best_val_rmse: 0.4535 (from epoch 1)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 79 val_rmse: 0.4531
# New best_val_rmse: 0.4531
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4527
# New best_val_rmse: 0.4527
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 81 val_rmse: 0.4523
# New best_val_rmse: 0.4523
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4521
# New best_val_rmse: 0.4521
#
# 1 steps took 0.434 seconds
# Epoch: 2 batch_num: 83 val_rmse: 0.4518
# New best_val_rmse: 0.4518
#
# 1 steps took 0.438 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4517
# New best_val_rmse: 0.4517
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.4517
# New best_val_rmse: 0.4517
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4518
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4521
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.433 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4524
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.4527
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4532
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.4538
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4545
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.4553
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4563
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.4568
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.436 seconds
# Epoch: 2 batch_num: 96 val_rmse: 0.4573
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 97 val_rmse: 0.4577
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4578
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.458
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.428 seconds
# Epoch: 2 batch_num: 100 val_rmse: 0.4584
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 101 val_rmse: 0.4589
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4594
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 103 val_rmse: 0.4598
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4602
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4606
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.433 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.461
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4613
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4618
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4622
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4625
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 111 val_rmse: 0.4625
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4625
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 113 val_rmse: 0.4626
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4626
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.4627
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4628
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.436 seconds
# Epoch: 2 batch_num: 117 val_rmse: 0.4628
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.463
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 119 val_rmse: 0.4628
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4628
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.4628
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4628
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 123 val_rmse: 0.4627
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4626
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 125 val_rmse: 0.4624
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4621
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4619
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.438 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4618
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4616
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4615
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4614
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4613
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4613
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.443 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.434 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4612
# Still best_val_rmse: 0.4517 (from epoch 2)
#
# Performance estimates:
# [0.4714620448305189, 0.4803465694155351, 0.45171087757471895]
# Mean: 0.4678398306069243
#
# Fold 4/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 7.42 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.055
# New best_val_rmse: 1.055
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7705
# New best_val_rmse: 0.7705
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6416
# New best_val_rmse: 0.6416
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.5911
# New best_val_rmse: 0.5911
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.5663
# New best_val_rmse: 0.5663
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5452
# New best_val_rmse: 0.5452
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5867
# Still best_val_rmse: 0.5452 (from epoch 0)
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5625
# Still best_val_rmse: 0.5452 (from epoch 0)
#
# 16 steps took 7.03 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5403
# New best_val_rmse: 0.5403
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.5004
# New best_val_rmse: 0.5004
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.5602
# Still best_val_rmse: 0.5004 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.5029
# Still best_val_rmse: 0.5004 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.5004
# Still best_val_rmse: 0.5004 (from epoch 1)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.4943
# New best_val_rmse: 0.4943
#
# 8 steps took 3.42 seconds
# Epoch: 1 batch_num: 91 val_rmse: 0.5538
# Still best_val_rmse: 0.4943 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 107 val_rmse: 0.5173
# Still best_val_rmse: 0.4943 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 123 val_rmse: 0.4834
# New best_val_rmse: 0.4834
#
# 4 steps took 1.71 seconds
# Epoch: 1 batch_num: 127 val_rmse: 0.4763
# New best_val_rmse: 0.4763
#
# 2 steps took 0.862 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.4771
# Still best_val_rmse: 0.4763 (from epoch 1)
#
# 2 steps took 0.852 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.4791
# Still best_val_rmse: 0.4763 (from epoch 1)
#
# 2 steps took 0.859 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.4908
# Still best_val_rmse: 0.4763 (from epoch 1)
#
# 8 steps took 3.62 seconds
# Epoch: 2 batch_num: 0 val_rmse: 0.4767
# Still best_val_rmse: 0.4763 (from epoch 1)
#
# 2 steps took 0.868 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.4852
# Still best_val_rmse: 0.4763 (from epoch 1)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.5019
# Still best_val_rmse: 0.4763 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4759
# New best_val_rmse: 0.4759
#
# 2 steps took 0.861 seconds
# Epoch: 2 batch_num: 24 val_rmse: 0.4772
# Still best_val_rmse: 0.4759 (from epoch 2)
#
# 2 steps took 0.862 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.4725
# New best_val_rmse: 0.4725
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 28 val_rmse: 0.4723
# New best_val_rmse: 0.4723
#
# 2 steps took 0.863 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.4681
# New best_val_rmse: 0.4681
#
# 1 steps took 0.441 seconds
# Epoch: 2 batch_num: 31 val_rmse: 0.4673
# New best_val_rmse: 0.4673
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 32 val_rmse: 0.4699
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.433 seconds
# Epoch: 2 batch_num: 33 val_rmse: 0.4737
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 35 val_rmse: 0.4847
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 39 val_rmse: 0.4879
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 43 val_rmse: 0.4685
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 44 val_rmse: 0.4681
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 45 val_rmse: 0.4688
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4688
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 47 val_rmse: 0.4699
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.434 seconds
# Epoch: 2 batch_num: 48 val_rmse: 0.4731
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4787
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 52 val_rmse: 0.4782
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 2 steps took 0.863 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4748
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 2 steps took 0.86 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4707
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4684
# Still best_val_rmse: 0.4673 (from epoch 2)
#
# 1 steps took 0.429 seconds
# Epoch: 2 batch_num: 59 val_rmse: 0.4673
# New best_val_rmse: 0.4673
#
# 1 steps took 0.433 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4661
# New best_val_rmse: 0.4661
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 61 val_rmse: 0.465
# New best_val_rmse: 0.465
#
# 1 steps took 0.441 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4644
# New best_val_rmse: 0.4644
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 63 val_rmse: 0.4642
# New best_val_rmse: 0.4642
#
# 1 steps took 0.438 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4643
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 1 steps took 0.43 seconds
# Epoch: 2 batch_num: 65 val_rmse: 0.4642
# New best_val_rmse: 0.4642
#
# 1 steps took 0.437 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4643
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 67 val_rmse: 0.4644
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4653
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 1 steps took 0.431 seconds
# Epoch: 2 batch_num: 69 val_rmse: 0.4669
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 1 steps took 0.432 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4694
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 1 steps took 0.435 seconds
# Epoch: 2 batch_num: 71 val_rmse: 0.4729
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 73 val_rmse: 0.4818
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 4 steps took 1.71 seconds
# Epoch: 2 batch_num: 77 val_rmse: 0.4914
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 8 steps took 3.42 seconds
# Epoch: 2 batch_num: 85 val_rmse: 0.4764
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.864 seconds
# Epoch: 2 batch_num: 87 val_rmse: 0.4736
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 89 val_rmse: 0.4719
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 91 val_rmse: 0.471
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 93 val_rmse: 0.4704
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 95 val_rmse: 0.4704
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.863 seconds
# Epoch: 2 batch_num: 97 val_rmse: 0.4709
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.865 seconds
# Epoch: 2 batch_num: 99 val_rmse: 0.4712
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.861 seconds
# Epoch: 2 batch_num: 101 val_rmse: 0.4721
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 103 val_rmse: 0.4731
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 105 val_rmse: 0.4745
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.859 seconds
# Epoch: 2 batch_num: 107 val_rmse: 0.4763
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.864 seconds
# Epoch: 2 batch_num: 109 val_rmse: 0.4777
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 111 val_rmse: 0.4784
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.861 seconds
# Epoch: 2 batch_num: 113 val_rmse: 0.4793
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 115 val_rmse: 0.4796
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 117 val_rmse: 0.4793
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.867 seconds
# Epoch: 2 batch_num: 119 val_rmse: 0.479
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.854 seconds
# Epoch: 2 batch_num: 121 val_rmse: 0.4789
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.858 seconds
# Epoch: 2 batch_num: 123 val_rmse: 0.4784
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 125 val_rmse: 0.4781
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.859 seconds
# Epoch: 2 batch_num: 127 val_rmse: 0.4778
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.853 seconds
# Epoch: 2 batch_num: 129 val_rmse: 0.4776
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.855 seconds
# Epoch: 2 batch_num: 131 val_rmse: 0.4773
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.868 seconds
# Epoch: 2 batch_num: 133 val_rmse: 0.4771
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.857 seconds
# Epoch: 2 batch_num: 135 val_rmse: 0.477
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.852 seconds
# Epoch: 2 batch_num: 137 val_rmse: 0.477
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# 2 steps took 0.856 seconds
# Epoch: 2 batch_num: 139 val_rmse: 0.477
# Still best_val_rmse: 0.4642 (from epoch 2)
#
# Performance estimates:
# [0.4714620448305189, 0.4803465694155351, 0.45171087757471895, 0.4642297284746963]
# Mean: 0.4669373050738673
#
# Fold 5/5
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 7.42 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.8833
# New best_val_rmse: 0.8833
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7887
# New best_val_rmse: 0.7887
#
# 16 steps took 6.85 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7105
# New best_val_rmse: 0.7105
#
# 16 steps took 6.86 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6079
# New best_val_rmse: 0.6079
#
# 16 steps took 6.84 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6636
# Still best_val_rmse: 0.6079 (from epoch 0)
#
# 16 steps took 6.82 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5556
# New best_val_rmse: 0.5556
#
# 16 steps took 6.83 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5564
# Still best_val_rmse: 0.5556 (from epoch 0)
#
# 16 steps took 6.82 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.5545
# New best_val_rmse: 0.5545
#
# 16 steps took 7.05 seconds
# Epoch: 1 batch_num: 3 val_rmse: 0.5244
# New best_val_rmse: 0.5244
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 19 val_rmse: 0.5707
# Still best_val_rmse: 0.5244 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 35 val_rmse: 0.5287
# Still best_val_rmse: 0.5244 (from epoch 1)
#
# 16 steps took 6.85 seconds
# Epoch: 1 batch_num: 51 val_rmse: 0.5454
# Still best_val_rmse: 0.5244 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 67 val_rmse: 0.5587
# Still best_val_rmse: 0.5244 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 1 batch_num: 83 val_rmse: 0.5209
# New best_val_rmse: 0.5209
#
# 16 steps took 6.86 seconds
# Epoch: 1 batch_num: 99 val_rmse: 0.5403
# Still best_val_rmse: 0.5209 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 115 val_rmse: 0.5268
# Still best_val_rmse: 0.5209 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 1 batch_num: 131 val_rmse: 0.5375
# Still best_val_rmse: 0.5209 (from epoch 1)
#
# 16 steps took 7.03 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.5275
# Still best_val_rmse: 0.5209 (from epoch 1)
#
# 16 steps took 6.83 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.5232
# Still best_val_rmse: 0.5209 (from epoch 1)
#
# 16 steps took 6.84 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.5173
# New best_val_rmse: 0.5173
#
# 16 steps took 6.84 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.529
# Still best_val_rmse: 0.5173 (from epoch 2)
#
# 16 steps took 6.82 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.5224
# Still best_val_rmse: 0.5173 (from epoch 2)
#
# 16 steps took 6.82 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.5131
# New best_val_rmse: 0.5131
#
# 16 steps took 6.83 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.5116
# New best_val_rmse: 0.5116
#
# 16 steps took 6.83 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.5144
# Still best_val_rmse: 0.5116 (from epoch 2)
#
# 16 steps took 6.83 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.5159
# Still best_val_rmse: 0.5116 (from epoch 2)
#
# Performance estimates:
# [0.4714620448305189, 0.4803465694155351, 0.45171087757471895, 0.4642297284746963, 0.5116021742747928]
# Mean: 0.4758702789140524

# %% [markdown]
# # Inference

# %%
test_dataset = LitDataset(test_df, inference_only=True)

# %%
all_predictions = np.zeros((len(list_val_rmse), len(test_df)))

test_dataset = LitDataset(test_df, inference_only=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         drop_last=False, shuffle=False, num_workers=2)

for index in range(len(list_val_rmse)):            
    model_path = f"model_{index + 1}.pth"
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    
    model.to(DEVICE)
    
    all_predictions[index] = predict(model, test_loader)
    
    del model
    gc.collect()
# Out:
# Using model_1.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_2.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_3.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_4.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using model_5.pth
# Some weights of the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at ../input/commonlitreadabilityprize/pretrained-model/clrp_roberta_base/ and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
predictions = all_predictions.mean(axis=0)
submission_df.target = predictions
print(submission_df)
submission_df.to_csv("submission.csv", index=False)
# Out:
#           id    target
# 0  c0f722661 -0.351897
# 1  f0953f0a5 -0.604154
# 2  0df072751 -0.300854
# 3  04caf4e0c -2.505731
# 4  0e63f8bea -1.662875
# 5  12537fe78 -1.377436
# 6  965e592c0  0.140298

# %% [markdown]
# # Upload data

# %%
# !date +"%Y%m%d%I%M%S"
# Out:
# 20210703061537

# %%
# !mkdir -p ./output/
# !cp -f ./model* ./output/
# !cp -f ./drive/MyDrive/kaggle/commonlit/Lightweight-Roberta-base/dataset-metadata.json ./output/
# !sed -i -e "s/lightweight-roberta-base/lightweight-roberta-base-`date +"%Y%m%d%I%M%S"`/" ./output/dataset-metadata.json

# %%
# !cat ./output/dataset-metadata.json
# Out:
# {
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ],
#   "id": "iamnishipy/lightweight-roberta-base-20210703061557",
#   "title": "Lightweight-Roberta-base"
# }

# %%
# !mkdir -p ./output/
# !cp -f ./model* ./output/
# !cp -f ./drive/MyDrive/kaggle/commonlit/Lightweight-Roberta-base/dataset-metadata-maxlen.json ./output/dataset-metadata.json
# !sed -i -e "s/lightweight-roberta-base/lightweight-roberta-base-`date +"%Y%m%d%I%M%S"`/" ./output/dataset-metadata.json
# !kaggle datasets create -p ./output/
# Out:
# Starting upload for file model_3.pth
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# 100% 477M/477M [00:19<00:00, 25.9MB/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_5.pth
# 100% 477M/477M [00:21<00:00, 22.9MB/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_4.pth
# 100% 477M/477M [00:20<00:00, 24.3MB/s]
# Upload successful: model_4.pth (477MB)
# Starting upload for file model_2.pth
# 100% 477M/477M [00:20<00:00, 24.2MB/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_1.pth
# 100% 477M/477M [00:20<00:00, 24.6MB/s]
# Upload successful: model_1.pth (477MB)
# Your private Dataset is being created. Please check progress at /api/v1/datasets/status//iamnishipy/lightweight-roberta-base-20210703061626-maxlen
